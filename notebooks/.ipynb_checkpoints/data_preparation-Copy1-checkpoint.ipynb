# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ## Label Studio

# %%
# %%bash
# ## For label-studio data
# cd ../data/label-studio
# python verify_empty_images.py
# python delete_empty.py
# python rename.py
# python rename_empty_label_studio.py
# mv Unannotated_Images/* images/
# python rename.py
# python verify.py
# Out:
# 0ca33eec-1662725797.jpg has been copied to Unannotated_Images folder.
# 1c70f05e-1662714468.jpg has been copied to Unannotated_Images folder.
# 23fa6c19-1662712441.jpg has been copied to Unannotated_Images folder.
# 2771ff68-1662730272.jpg has been copied to Unannotated_Images folder.
# 288985e6-1662727506.jpg has been copied to Unannotated_Images folder.
# 381c3e55-1662725844.jpg has been copied to Unannotated_Images folder.
# 4b15eb82-1662713295.jpg has been copied to Unannotated_Images folder.
# 6222904d-1662716343.jpg has been copied to Unannotated_Images folder.
# 693ade8a-1662712695.jpg has been copied to Unannotated_Images folder.
# 6dac0a93-1662725813.jpg has been copied to Unannotated_Images folder.
# 77d0ae90-1662719158.jpg has been copied to Unannotated_Images folder.
# 95e92871-1662732463.jpg has been copied to Unannotated_Images folder.
# a1261af2-1662716901.jpg has been copied to Unannotated_Images folder.
# ...

# %%
im1 = Image.open("../data/label-studio/images_processed/0001.jpg")
im2 = Image.open("../data/label-studio/images_processed/0100.jpg")
im3 = Image.open("../data/label-studio/images_processed/0250.jpg")
im4 = Image.open("../data/label-studio/images_processed/0500.jpg")
im5 = Image.open("../data/label-studio/images_processed/0920.jpg")

# %%
plt.imshow(im1)
plt.show()
plt.imshow(im2)
plt.show()
plt.imshow(im3)
plt.show()
plt.imshow(im4)
plt.show()
plt.imshow(im5)
plt.show()

# %%
ls ../data/roboflow/images
# Out:
# 1608644703_2_jpg.rf.2cdedcffc999cbdd4f768f6dfde71764.jpg*
# 1608644703_7_jpg.rf.4e284175d229b4c5ec491db5e345e6e7.jpg*
# 1608644703_jpg.rf.acd73f9391bfa3c6f191630f2d21986f.jpg*
# 1608644746_4_jpg.rf.3be379a6cc4d2287e6365ba730536a83.jpg*
# 1608644746_5_jpg.rf.c190a531924975491ecf027f380d6738.jpg*
# 1608644746_7_jpg.rf.503f431921c12efe8eb9492761363b2c.jpg*
# 1608644746_jpg.rf.144ea58c2c6b9e0b9bb190450d909c82.jpg*
# 1608644799_5_jpg.rf.589c10cd687f649bc1efe65da4b449a0.jpg*
# 1608645146_0_jpg.rf.76855f3d03efb9c87bb26a3eaa44e76f.jpg*
# 1608645146_6_jpg.rf.64e301f299b4019ab292b40a96f545bb.jpg*
# 1608645179_1_jpg.rf.7a5329a9edcd8e80e7ad5cdc57a68b2f.jpg*
# 1608645179_5_jpg.rf.8edd3d33d30cc0a3e53f59329dbbfe95.jpg*
# 1608645310_4_jpg.rf.26ea3173da473be2444fbe2359c66d84.jpg*
# 1608645310_9_jpg.rf.b4ffcf5e613a9cd459a0dea418fddd11.jpg*
# 1608645310_jpg.rf.f328dc4b03eeef14b337fc6817172f2f.jpg*
# 1608645513_1_jpg.rf.1c22d3e2f7f1326ecdaf44c2e7c5d819.jpg*
# ...

# %%
# %%bash
# ## On fusionne les données préparées de label studio et le dataset de roboflow avant de le traiter.
# cd ../data/label-studio
# mv images/* ../roboflow/images
# mv Annotations/* ../roboflow/Annotations

# %% [markdown]
# ## Roboflow

# %%
# %%bash
#
# cd ../data/roboflow
# python rename.py
# python verify.py

# %%
im1 = Image.open("../data/roboflow/images_processed/0001.jpg")
im2 = Image.open("../data/roboflow/images_processed/0100.jpg")
im3 = Image.open("../data/roboflow/images_processed/0250.jpg")
im4 = Image.open("../data/roboflow/images_processed/0500.jpg")
im5 = Image.open("../data/roboflow/images_processed/1000.jpg")
im6 = Image.open("../data/roboflow/images_processed/1250.jpg")
im7 = Image.open("../data/roboflow/images_processed/1500.jpg")
im8 = Image.open("../data/roboflow/images_processed/2000.jpg")
im9 = Image.open("../data/roboflow/images_processed/2250.jpg")
im10 = Image.open("../data/roboflow/images_processed/2500.jpg")

# %%
plt.imshow(im1)
plt.show()
plt.imshow(im2)
plt.show()
plt.imshow(im3)
plt.show()
plt.imshow(im4)
plt.show()
plt.imshow(im5)
plt.show()
plt.imshow(im6)
plt.show()
plt.imshow(im7)
plt.show()
plt.imshow(im8)
plt.show()
plt.imshow(im9)
plt.show()
plt.imshow(im10)
plt.show()

# %%
# %%bash
# ## On zip le dataset complet et on le déplace dans le dossier /data
# cd ../data/roboflow
# zip -r full_dataset.zip images Annotations
# mv full_dataset.zip ../
# Out:
# Scanning files
#   adding: images/ (stored 0%)
#   adding: images/0001.jpg (deflated 0%)
#   adding: images/0002.jpg (deflated 0%)
#   adding: images/0003.jpg (deflated 0%)
#   adding: images/0004.jpg (deflated 0%)
#   adding: images/0005.jpg (deflated 0%)
#   adding: images/0006.jpg (deflated 0%)
#   adding: images/0007.jpg (deflated 0%)
#   adding: images/0008.jpg (deflated 0%)
#   adding: images/0009.jpg (deflated 0%)
#   adding: images/0010.jpg (deflated 0%)
#   adding: images/0011.jpg (deflated 0%)
#   adding: images/0012.jpg (deflated 0%)
#   adding: images/0013.jpg (deflated 0%)
#   adding: images/0014.jpg (deflated 0%)
#   adding: images/0015.jpg (deflated 0%)
#   adding: images/0016.jpg (deflated 0%)
#   adding: images/0017.jpg (deflated 0%)
#   adding: images/0018.jpg (deflated 0%)
#   adding: images/0019.jpg (deflated 0%)
#   adding: images/0020.jpg (deflated 0%)
#   adding: images/0021.jpg (deflated 0%)
#   adding: images/0022.jpg (deflated 0%)
# ...
