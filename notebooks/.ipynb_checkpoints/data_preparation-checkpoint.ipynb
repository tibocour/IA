# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
# %%bash
# ## For label-studio data
# cd ../data/label-studio
# python verify_empty_images.py
# Out:
# 0ca33eec-1662725797.jpg has been copied to Unannotated_Images folder.
# 1c70f05e-1662714468.jpg has been copied to Unannotated_Images folder.
# 23fa6c19-1662712441.jpg has been copied to Unannotated_Images folder.
# 2771ff68-1662730272.jpg has been copied to Unannotated_Images folder.
# 288985e6-1662727506.jpg has been copied to Unannotated_Images folder.
# 381c3e55-1662725844.jpg has been copied to Unannotated_Images folder.
# 4b15eb82-1662713295.jpg has been copied to Unannotated_Images folder.
# 6222904d-1662716343.jpg has been copied to Unannotated_Images folder.
# 693ade8a-1662712695.jpg has been copied to Unannotated_Images folder.
# 6dac0a93-1662725813.jpg has been copied to Unannotated_Images folder.
# 77d0ae90-1662719158.jpg has been copied to Unannotated_Images folder.
# 95e92871-1662732463.jpg has been copied to Unannotated_Images folder.
# a1261af2-1662716901.jpg has been copied to Unannotated_Images folder.
# ...

# %%
# %%bash
# ## For label-studio data
# cd ../data/label-studio
# python delete_empty.py
# Out:
# 0ca33eec-1662725797.jpg has been deleted because it does not have a corresponding annotation file.
# 1c70f05e-1662714468.jpg has been deleted because it does not have a corresponding annotation file.
# 23fa6c19-1662712441.jpg has been deleted because it does not have a corresponding annotation file.
# 2771ff68-1662730272.jpg has been deleted because it does not have a corresponding annotation file.
# 288985e6-1662727506.jpg has been deleted because it does not have a corresponding annotation file.
# 381c3e55-1662725844.jpg has been deleted because it does not have a corresponding annotation file.
# 4b15eb82-1662713295.jpg has been deleted because it does not have a corresponding annotation file.
# 6222904d-1662716343.jpg has been deleted because it does not have a corresponding annotation file.
# 693ade8a-1662712695.jpg has been deleted because it does not have a corresponding annotation file.
# ...

# %%
# %%bash
# ## For label-studio data
# cd ../data/label-studio
# python rename.py

# %%
# %%bash
# ## For label-studio data
# cd ../data/label-studio
# python rename_empty_label_studio.py
# Out:
# Created Annotations/0ca33eec-1662725797.xml because it did not have a corresponding annotation file.
# Created Annotations/1c70f05e-1662714468.xml because it did not have a corresponding annotation file.
# Created Annotations/23fa6c19-1662712441.xml because it did not have a corresponding annotation file.
# Created Annotations/2771ff68-1662730272.xml because it did not have a corresponding annotation file.
# Created Annotations/288985e6-1662727506.xml because it did not have a corresponding annotation file.
# Created Annotations/381c3e55-1662725844.xml because it did not have a corresponding annotation file.
# Created Annotations/4b15eb82-1662713295.xml because it did not have a corresponding annotation file.
# Created Annotations/6222904d-1662716343.xml because it did not have a corresponding annotation file.
# Created Annotations/693ade8a-1662712695.xml because it did not have a corresponding annotation file.
# ...

# %%
# %%bash
#
# cd ../data/label-studio
# mv Unannotated_Images/* images/

# %%
# %%bash
# ## For label-studio data
# cd ../data/label-studio
# python rename.py

# %%
# %%bash
# ## For label-studio data
# cd ../data/label-studio
# python verify.py
# Out:
# Traceback (most recent call last):
#   File "/mnt/c/Users/axelb/Bureau/Work/BirdsForChange/IA/data/label-studio/verify.py", line 45, in <module>
#     cv2.destroyAllWindows()
# cv2.error: OpenCV(4.7.0) /io/opencv/modules/highgui/src/window.cpp:1266: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '## For label-studio data\ncd ../data/label-studio\npython verify.py\n')
#
# File ~/.pyenv/versions/miniconda3-latest/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
# ...

# %%
im1 = Image.open("../data/label-studio/images_processed/0001.jpg")
im2 = Image.open("../data/label-studio/images_processed/0010.jpg")
im3 = Image.open("../data/label-studio/images_processed/0020.jpg")
im4 = Image.open("../data/label-studio/images_processed/0001.jpg")
im5 = Image.open("../data/label-studio/images_processed/0001.jpg")

# %%
plt.imshow(im1)

plt.imshow(im2)
plt.show()
