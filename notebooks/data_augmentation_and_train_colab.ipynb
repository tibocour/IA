# %%
import os
from getpass import getpass
from PIL import Image
import matplotlib.pyplot as plt

# %%
user = getpass('GitHub user')
password = getpass('GitHub password')
os.environ['GITHUB_AUTH'] = user + ':' + password
# Out:
# GitHub user··········
# GitHub password··········

# %%
# %%shell
#
# git clone https://$GITHUB_AUTH@github.com/tibocour/IA.git
# Out:
# Cloning into 'IA'...
# remote: Enumerating objects: 5569, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 5569 (delta 137), reused 239 (delta 130), pack-reused 5321
# Receiving objects: 100% (5569/5569), 190.94 MiB | 32.27 MiB/s, done.
# Resolving deltas: 100% (2720/2720), done.

# %%
# %%shell
#
# pip install -r IA/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imgaug in /usr/local/lib/python3.8/dist-packages (from -r IA/requirements.txt (line 1)) (0.4.0)
# Collecting pascal-voc-writer
#   Downloading pascal_voc_writer-0.1.4-py2.py3-none-any.whl (4.0 kB)
# Collecting tflite-model-maker-nightly
#   Downloading tflite_model_maker_nightly-0.4.3.dev202302280608-py3-none-any.whl (577 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.8/577.8 KB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.8/dist-packages (from -r IA/requirements.txt (line 4)) (2.0.6)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.8/dist-packages (from -r IA/requirements.txt (line 5)) (4.6.0.66)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from imgaug->-r IA/requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.8/dist-packages (from imgaug->-r IA/requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.8/dist-packages (from imgaug->-r IA/requirements.txt (line 1)) (0.18.3)
# Requirement already satisfied: imageio in /usr/local/lib/python3.8/dist-packages (from imgaug->-r IA/requirements.txt (line 1)) (2.9.0)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.8/dist-packages (from imgaug->-r IA/requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from imgaug->-r IA/requirements.txt (line 1)) (1.7.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from imgaug->-r IA/requirements.txt (line 1)) (3.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from imgaug->-r IA/requirements.txt (line 1)) (8.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from pascal-voc-writer->-r IA/requirements.txt (line 2)) (2.11.3)
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.12.0)
# Collecting fire>=0.3.1
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting neural-structured-learning>=1.3.1
#   Downloading neural_structured_learning-1.4.0-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 KB 16.5 MB/s eta 0:00:00
# Collecting tensorflow-model-optimization>=0.5
#   Downloading tensorflow_model_optimization-0.7.3-py2.py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 KB 27.8 MB/s eta 0:00:00
# Collecting matplotlib
#   Downloading matplotlib-3.4.3-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 80.8 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (23.1.21)
# Collecting tensorflowjs<3.19.0,>=2.4.0
#   Downloading tensorflowjs-3.18.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 KB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.24.3)
# Requirement already satisfied: tensorflow-datasets>=2.1.0 in /usr/local/lib/python3.8/dist-packages (from tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (4.8.2)
# Requirement already satisfied: tensorflow>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (2.11.0)
# Collecting scann==1.2.6
#   Downloading scann-1.2.6-cp38-cp38-manylinux2014_x86_64.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 82.2 MB/s eta 0:00:00
# Collecting tf-models-official==2.3.0
#   Downloading tf_models_official-2.3.0-py2.py3-none-any.whl (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 KB 58.5 MB/s eta 0:00:00
# Collecting numba==0.53
#   Downloading numba-0.53.0-cp38-cp38-manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 86.8 MB/s eta 0:00:00
# Requirement already satisfied: librosa==0.8.1 in /usr/local/lib/python3.8/dist-packages (from tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.8.1)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.8/dist-packages (from tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (6.0)
# Collecting tflite-support-nightly
#   Downloading tflite_support_nightly-0.4.4.dev20221103-cp38-cp38-manylinux2014_x86_64.whl (60.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 MB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: lxml>=4.6.1 in /usr/local/lib/python3.8/dist-packages (from tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (4.9.2)
# Collecting sentencepiece>=0.1.91
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.0 MB/s eta 0:00:00
# Collecting tfa-nightly
#   Downloading tfa_nightly-0.20.0.dev20221214152534-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 49.1 MB/s eta 0:00:00
# Requirement already satisfied: Cython>=0.29.13 in /usr/local/lib/python3.8/dist-packages (from tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.29.33)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.1->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.1->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.1->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.0.2)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.1->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.4.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.1->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (23.0)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.1->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (4.4.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.1->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.1->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (3.0.0)
# Collecting llvmlite<0.37,>=0.36.0rc1
#   Downloading llvmlite-0.36.0-cp38-cp38-manylinux2010_x86_64.whl (25.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 36.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba==0.53->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (57.4.0)
# Collecting tensorflow>=2.6.0
#   Downloading tensorflow-2.8.4-cp38-cp38-manylinux2010_x86_64.whl (498.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.0/498.0 MB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.8/dist-packages (from tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.5.12)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.8/dist-packages (from tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.3.5)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.8/dist-packages (from tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (2.70.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 54.2 MB/s eta 0:00:00
# Requirement already satisfied: gin-config in /usr/local/lib/python3.8/dist-packages (from tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.5.0)
# Collecting tf-slim>=1.1.0
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 KB 33.6 MB/s eta 0:00:00
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.8/dist-packages (from tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (5.4.8)
# Collecting py-cpuinfo>=3.3.0
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: google-cloud-bigquery>=0.31.0 in /usr/local/lib/python3.8/dist-packages (from tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (3.4.2)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.8/dist-packages (from tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (4.7.0.72)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.8/dist-packages (from fire>=0.3.1->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug->-r IA/requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug->-r IA/requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug->-r IA/requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug->-r IA/requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.8/dist-packages (from neural-structured-learning>=1.3.1->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (22.2.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.14.2->imgaug->-r IA/requirements.txt (line 1)) (3.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.14.2->imgaug->-r IA/requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.14.2->imgaug->-r IA/requirements.txt (line 1)) (2023.2.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.6.3)
# Collecting tensorflow-estimator<2.9,>=2.8
#   Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 KB 34.0 MB/s eta 0:00:00
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.51.3)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.14.1)
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 69.8 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.30.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.4.0)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 4.5 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 58.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (4.5.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (3.3.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (15.0.6.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (3.19.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (2.25.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.1.8)
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.10.2)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (7.1.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.3.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (4.64.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (5.12.0)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.12.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (2.3)
# Collecting packaging>=20.0
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 KB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->pascal-voc-writer->-r IA/requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tfa-nightly->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (2.7.1)
# Collecting pybind11>=2.6.0
#   Downloading pybind11-2.10.3-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.4/222.4 KB 21.5 MB/s eta 0:00:00
# Collecting sounddevice>=0.4.4
#   Downloading sounddevice-0.4.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.38.4)
# Requirement already satisfied: zipp in /usr/local/lib/python3.8/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets>=2.1.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (3.14.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (2.11.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.1.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (2.16.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.17.4)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (4.1.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-bigquery>=0.31.0->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (2.4.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-bigquery>=0.31.0->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.22.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from google-cloud-bigquery>=0.31.0->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (2.3.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.8/dist-packages (from kaggle>=1.3.9->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (8.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from kaggle>=1.3.9->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (2022.12.7)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.22.0->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (2022.7.1)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.0->librosa==0.8.1->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->tensorflow-datasets>=2.1.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->tensorflow-datasets>=2.1.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.8.1->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.8/dist-packages (from sounddevice>=0.4.4->tflite-support-nightly->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.15.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.6.1)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-metadata->tensorflow-datasets>=2.1.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.58.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->tflite-support-nightly->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (2.21)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.48.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.8/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery>=0.31.0->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (6.0.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.8/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker-nightly->-r IA/requirements.txt (line 3)) (3.2.2)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116949 sha256=3506fbd569d6f8d0b24a91d55a89ce33b9dc7f6d1e46a43c4d84c4c16a57ed2c
#   Stored in directory: /root/.cache/pip/wheels/5b/eb/43/7295e71293b218ddfd627f935229bf54af9018add7fbb5aac6
# Successfully built fire
# Installing collected packages: tensorflow-estimator, sentencepiece, py-cpuinfo, keras, dataclasses, tf-slim, tensorflow-model-optimization, pybind11, packaging, llvmlite, keras-preprocessing, fire, tfa-nightly, tensorflow-addons, sounddevice, pascal-voc-writer, numba, neural-structured-learning, matplotlib, tflite-support-nightly, tensorboard, tensorflow, tf-models-official, tensorflowjs, scann, tflite-model-maker-nightly
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.0
#     Uninstalling packaging-23.0:
#       Successfully uninstalled packaging-23.0
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.39.1
#     Uninstalling llvmlite-0.39.1:
#       Successfully uninstalled llvmlite-0.39.1
#   Attempting uninstall: numba
#     Found existing installation: numba 0.56.4
#     Uninstalling numba-0.56.4:
#       Successfully uninstalled numba-0.56.4
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.3
#     Uninstalling matplotlib-3.5.3:
#       Successfully uninstalled matplotlib-3.5.3
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0
#     Uninstalling tensorflow-2.11.0:
#       Successfully uninstalled tensorflow-2.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2022.12.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.
# Successfully installed dataclasses-0.6 fire-0.5.0 keras-2.8.0 keras-preprocessing-1.1.2 llvmlite-0.36.0 matplotlib-3.4.3 neural-structured-learning-1.4.0 numba-0.53.0 packaging-20.9 pascal-voc-writer-0.1.4 py-cpuinfo-9.0.0 pybind11-2.10.3 scann-1.2.6 sentencepiece-0.1.97 sounddevice-0.4.6 tensorboard-2.8.0 tensorflow-2.8.4 tensorflow-addons-0.19.0 tensorflow-estimator-2.8.0 tensorflow-model-optimization-0.7.3 tensorflowjs-3.18.0 tf-models-official-2.3.0 tf-slim-1.1.0 tfa-nightly-0.20.0.dev20221214152534 tflite-model-maker-nightly-0.4.3.dev202302280608 tflite-support-nightly-0.4.4.dev20221103

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%shell
# cp -r /content/drive/MyDrive/full_dataset.zip /content/IA/data

# %%
database = "IA/data/full_dataset.zip"

# %%
os.environ.update({"database": database})

# %%
# %%bash
#
# python IA/python/label_studio_voc_converter.py --zip IA/data/full_dataset.zip
# Out:
# created zip temporary directory: /tmp/tmp2yqn7x_z
# extract zip file IA/data/full_dataset.zip in /tmp/tmp2yqn7x_z
#  * number of xml files : 2673
#  * train size : 2138
#  * valid size : 535
# created dataset temporary directory: /tmp/tmpcm8uctxk
# create annotations and images directories
# create dataset train with params {'xml_files': ['/tmp/tmp2yqn7x_z/Annotations/0711.xml', '/tmp/tmp2yqn7x_z/Annotations/1694.xml', '/tmp/tmp2yqn7x_z/Annotations/0197.xml', '/tmp/tmp2yqn7x_z/Annotations/0062.xml', '/tmp/tmp2yqn7x_z/Annotations/2157.xml', '/tmp/tmp2yqn7x_z/Annotations/1966.xml', '/tmp/tmp2yqn7x_z/Annotations/1552.xml', '/tmp/tmp2yqn7x_z/Annotations/0582.xml', '/tmp/tmp2yqn7x_z/Annotations/2342.xml', '/tmp/tmp2yqn7x_z/Annotations/0097.xml', '/tmp/tmp2yqn7x_z/Annotations/0340.xml', '/tmp/tmp2yqn7x_z/Annotations/0475.xml', '/tmp/tmp2yqn7x_z/Annotations/2329.xml', '/tmp/tmp2yqn7x_z/Annotations/2478.xml', '/tmp/tmp2yqn7x_z/Annotations/1943.xml',
z/Annotations/1475.xml', '/tmp/tmp2yqn7x_z/Annotations/2444.xml', '/tmp/tmp2yqn7x_z/Annotations/0497.xml', '/tmp/tmp2yqn7x_z/Annotations/0170.xml', '/tmp/tmp2yqn7x_z/Annotations/0896.xml', '/tmp/tmp2yqn7x_z/Annotations/0596.xml', '/tmp/tmp2yqn7x_z/Annotations/0693.xml', '/tmp/tmp2yqn7x_z/Annotations/0174.xml', '/tmp/tmp2yqn7x_z/Annotations/1763.xml', '/tmp/tmp2yqn7x_z/Annotations/0694.xml', '/tmp/tmp2yqn7x_z/Annotations/1501.xml', '/tmp/tmp2yqn7x_z/Annotations/0965.xml', '/tmp/tmp2yqn7x_z/Annotations/2379.xml', '/tmp/tmp2yqn7x_z/Annotations/1364.xml', '/tmp/tmp2yqn7x_z/Annotations/0884.xml', '/tmp/tmp2yqn7x_z/Annotations/1500.xml', '/tmp/tmp2yqn7x_ ...
# create file / extension mapping
# created zip file: valid_full_dataset.zip

# %%
train = "train_full_dataset.zip"
valid = "valid_full_dataset.zip"

# %%
os.environ.update({"train": database})
os.environ.update({"valid": database})

# %%
# %%shell
#
# python IA/python/train.py \
#   --train_zip /content/train_full_dataset.zip \
#   --valid_zip /content/valid_full_dataset.zip
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.4 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# Tensorflow version : 2.8.4
# args : Namespace(batch_size=10, epochs=50, train_zip='/content/train_full_dataset.zip', valid_zip='/content/valid_full_dataset.zip', with_tflite_eval=0)
# created zip temporary directory: /tmp/tmp_9xsx9x0
# extract zip file /content/train_full_dataset.zip in /tmp/tmp_9xsx9x0/train
# labels : ['bouchon', 'caillou', 'capsule', 'croquette', 'ecorce', 'feuille', 'megot', 'vide']
# extract zip file /content/valid_full_dataset.zip in /tmp/tmp_9xsx9x0/valid
# labels : ['bouchon', 'caillou', 'capsule', 'croquette', 'ecorce', 'feuille', 'megot']
# * train dataset len : 23518
# * valid dataset len : 535
# 2023-02-28 15:18:27.287525: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-28 15:18:46.999707: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# Epoch 1/50
# 2023-02-28 15:19:25.753209: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 16384000 exceeds 10% of free system memory.
# 2023-02-28 15:19:35.376145: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 16384000 exceeds 10% of free system memory.
# 2023-02-28 15:19:35.404733: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 16384000 exceeds 10% of free system memory.
# 2023-02-28 15:19:35.572408: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 16384000 exceeds 10% of free system memory.
# 2023-02-28 15:19:35.593161: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 16384000 exceeds 10% of free system memory.

# %%
# %%shell
#
# rm -rf /tmp/images /tmp/annotations
# unzip -q IA/data/$valid -d /tmp
#
# ls /tmp/images

# %%
# %%shell
#
# # Change to the directory that contains the script
# cd /content/IA/python/google-coral-inference/
#
# # Create a new directory to save the processed images
# output_dir="/content/valid_processed"
# mkdir -p "$output_dir"
#
# # Loop through all the images in the input directory
# for filename in /tmp/images/*.jpg; do
#   # Get the input and output paths
#   input_path="$filename"
#   output_path="$output_dir/$(basename "$filename")"
#
#   # Run object detection on the image
#   python3 detect_image.py \
#     --model /content/efficientdet-lite-bfc.tflite \
#     --labels /content/bfc-labels.txt \
#     --input "$input_path" \
#     --output "$output_path"
# done
